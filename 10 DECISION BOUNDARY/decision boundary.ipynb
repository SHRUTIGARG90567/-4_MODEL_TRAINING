# %%
from  sklearn import datasets

# %%
df = datasets.load_iris()

# %%
list(df.keys())
# Out:
# ['data',
#  'target',
#  'frame',
#  'target_names',
#  'DESCR',
#  'feature_names',
#  'filename',
#  'data_module']

# %%
x = df["data"][:, 3:]

# %%
import numpy as np
y= (df["target"] == 2 ).astype(np.int64)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(x,y)
# Out:
# LogisticRegression()

# %%
import matplotlib.pyplot as plt
x_new = np.linspace(0, 3, 1000).reshape(-1,1)
y_prob = log_reg.predict_proba(x_new)
plt.plot(x_new, y_prob[:, 1], "g-", label = " IrisVirginica")
plt.plot(x_new, y_prob[:, 0], "b--", label = "non  IrisVirginica")

# %%
# creating the decision boundary

# %%
log_reg.predict([[1.7], [1.5]])
# Out:
# array([1, 0], dtype=int64)

# %%
# Generate a grid of points
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
h = 0.02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Classify the grid points
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary and data points
plt.figure()
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdBu)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.RdBu, edgecolors='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Decision Boundary - Iris Virginica')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Generate a grid of points
#       2 x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
# ----> 3 y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
#       4 h = 0.02  # step size in the mesh
#       5 xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.linear_model import LogisticRegression

# Load the iris dataset
iris = datasets.load_iris()
X = iris.data[:, :2]  # Take the first two features
y = (iris.target == 2).astype(int)  # Binary classification: Iris virginica or not

# Train a logistic regression model
model = LogisticRegression()
model.fit(X, y)

# Generate a grid of points
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = 0.02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Classify the grid points
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary and data points
plt.figure()
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdBu)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu, edgecolors='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Decision Boundary - Iris Virginica')
plt.show()
